# %% [markdown]
# <a href="https://colab.research.google.com/github/AKASH361/calculator/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('house.csv')
print(data.shape)
# (20640, 10)
# Out:
# (20640, 10)

# %%
data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
obj = (data.dtypes == 'object')

for col in list(obj[obj].index):
    data[col] = label_encoder.fit_transform(data[col])

# %%
data.ocean_proximity.value_counts()
# Out:
# 0    9136
# 1    6551
# 4    2658
# 3    2290
# 2       5
# Name: ocean_proximity, dtype: int64

# %%
for col in data.columns:
    data[col] = data[col].fillna(data[col].mean())

print(data.isna().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#import the necessary libraries required 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn import metrics

#%matplotlib notebook
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
house = pd.read_csv('house.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  int64
# dtypes: float64(4), int64(6)
# memory usage: 1.6 MB

# %%
house.dropna(inplace=True)

# %%
print("The number of rows and colums are {} and also called shape of the matrix".format(house.shape))
print("Columns names are \n {}".format(house.columns))
# Out:
# The number of rows and colums are (20433, 10) and also called shape of the matrix
# Columns names are
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
print(house.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
print(house.tail())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
print(house.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
#display scatter_matrix also
fig = plt.figure()
scatter_matrix(house,figsize =(25,25),alpha=0.9,diagonal="kde",marker="o");

# %%
house.hist(figsize=(25,25),bins=50);

# %%
hcorr = house.corr()
hcorr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0592a_row0_col0, #T_0592a_row1_col1, #T_0592a_row2_col2, #T_0592a_row3_col3, #T_0592a_row4_col4, #T_0592a_row5_col5, #T_0592a_row6_col6, #T_0592a_row7_col7, #T_0592a_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0592a_row0_col1, #T_0592a_row1_col0, #T_0592a_row1_col8, #T_0592a_row2_col3, #T_0592a_row2_col4, #T_0592a_row2_col5, #T_0592a_row2_col6, #T_0592a_row2_col7, #T_0592a_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0592a_row0_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_0592a_row0_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_0592a_row0_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_0592a_row0_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_0592a_row0_col6, #T_0592a_row1_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_0592a_row0_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_0592a_row0_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_0592a_row1_col3, #T_0592a_row7_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_0592a_row1_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_0592a_row1_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_0592a_row1_col6, #T_0592a_row7_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_0592a_row1_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_0592a_row2_col0, #T_0592a_row5_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_0592a_row2_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_0592a_row2_col8 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_0592a_row3_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_0592a_row3_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_0592a_row3_col4, #T_0592a_row4_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_0592a_row3_col5 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_0592a_row3_col6, #T_0592a_row6_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_0592a_row3_col7, #T_0592a_row8_col6 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_0592a_row3_col8, #T_0592a_row7_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_0592a_row4_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_0592a_row4_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_0592a_row4_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_0592a_row4_col5 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_0592a_row4_col6, #T_0592a_row6_col4 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_0592a_row4_col7, #T_0592a_row5_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_0592a_row4_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_0592a_row5_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_0592a_row5_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_0592a_row5_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_0592a_row5_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_0592a_row5_col6, #T_0592a_row6_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_0592a_row5_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_0592a_row6_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_0592a_row6_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_0592a_row6_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_0592a_row6_col7 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_0592a_row6_col8 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_0592a_row7_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_0592a_row7_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_0592a_row7_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_0592a_row7_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_0592a_row7_col8 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_0592a_row8_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_0592a_row8_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_0592a_row8_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_0592a_row8_col3 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_0592a_row8_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_0592a_row8_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_0592a_row8_col7 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0592a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >longitude</th>
#       <th class="col_heading level0 col1" >latitude</th>
#       <th class="col_heading level0 col2" >housing_median_age</th>
#       <th class="col_heading level0 col3" >total_rooms</th>
#       <th class="col_heading level0 col4" >total_bedrooms</th>
#       <th class="col_heading level0 col5" >population</th>
#       <th class="col_heading level0 col6" >households</th>
#       <th class="col_heading level0 col7" >median_income</th>
#       <th class="col_heading level0 col8" >median_house_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0592a_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_0592a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0592a_row0_col1" class="data row0 col1" >-0.924616</td>
#       <td id="T_0592a_row0_col2" class="data row0 col2" >-0.109357</td>
#       <td id="T_0592a_row0_col3" class="data row0 col3" >0.045480</td>
#       <td id="T_0592a_row0_col4" class="data row0 col4" >0.069608</td>
#       <td id="T_0592a_row0_col5" class="data row0 col5" >0.100270</td>
#       <td id="T_0592a_row0_col6" class="data row0 col6" >0.056513</td>
#       <td id="T_0592a_row0_col7" class="data row0 col7" >-0.015550</td>
#       <td id="T_0592a_row0_col8" class="data row0 col8" >-0.045398</td>
#     </tr>
#     <tr>
#       <th id="T_0592a_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_0592a_row1_col0" class="data row1 col0" >-0.924616</td>
#       <td id="T_0592a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0592a_row1_col2" class="data row1 col2" >0.011899</td>
#       <td id="T_0592a_row1_col3" class="data row1 col3" >-0.036667</td>
#       <td id="T_0592a_row1_col4" class="data row1 col4" >-0.066983</td>
#       <td id="T_0592a_row1_col5" class="data row1 col5" >-0.108997</td>
#       <td id="T_0592a_row1_col6" class="data row1 col6" >-0.071774</td>
#       <td id="T_0592a_row1_col7" class="data row1 col7" >-0.079626</td>
#       <td id="T_0592a_row1_col8" class="data row1 col8" >-0.144638</td>
#     </tr>
#     <tr>
#       <th id="T_0592a_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_0592a_row2_col0" class="data row2 col0" >-0.109357</td>
#       <td id="T_0592a_row2_col1" class="data row2 col1" >0.011899</td>
#       <td id="T_0592a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0592a_row2_col3" class="data row2 col3" >-0.360628</td>
#       <td id="T_0592a_row2_col4" class="data row2 col4" >-0.320451</td>
#       <td id="T_0592a_row2_col5" class="data row2 col5" >-0.295787</td>
#       <td id="T_0592a_row2_col6" class="data row2 col6" >-0.302768</td>
#       <td id="T_0592a_row2_col7" class="data row2 col7" >-0.118278</td>
#       <td id="T_0592a_row2_col8" class="data row2 col8" >0.106432</td>
#     </tr>
#     <tr>
#       <th id="T_0592a_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_0592a_row3_col0" class="data row3 col0" >0.045480</td>
#       <td id="T_0592a_row3_col1" class="data row3 col1" >-0.036667</td>
#       <td id="T_0592a_row3_col2" class="data row3 col2" >-0.360628</td>
#       <td id="T_0592a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0592a_row3_col4" class="data row3 col4" >0.930380</td>
#       <td id="T_0592a_row3_col5" class="data row3 col5" >0.857281</td>
#       <td id="T_0592a_row3_col6" class="data row3 col6" >0.918992</td>
#       <td id="T_0592a_row3_col7" class="data row3 col7" >0.197882</td>
#       <td id="T_0592a_row3_col8" class="data row3

# %%
#heatmap using seaborn
#set the context for plotting 
sns.set(context="paper",font="monospace")
housing_corr_matrix = house.corr()
#set the matplotlib figure
fig, axe = plt.subplots(figsize=(12,8))
#Generate color palettes 
cmap = sns.diverging_palette(220,10,center = "light", as_cmap=True)
#draw the heatmap
sns.heatmap(housing_corr_matrix,vmax=1,square =True, cmap=cmap,annot=True );

# %%
def getOutliers(dataframe,column):
    column = "total_rooms" 
    #housing[column].plot.box(figsize=(8,8))
    des = dataframe[column].describe()
    desPairs = {"count":0,"mean":1,"std":2,"min":3,"25":4,"50":5,"75":6,"max":7}
    Q1 = des[desPairs['25']]
    Q3 = des[desPairs['75']]
    IQR = Q3-Q1
    lowerBound = Q1-1.5*IQR
    upperBound = Q3+1.5*IQR
    print("(IQR = {})Outlier are anything outside this range: ({},{})".format(IQR,lowerBound,upperBound))
    #b = df[(df['a'] > 1) & (df['a'] < 5)]
    data = dataframe[(dataframe [column] < lowerBound) | (dataframe [column] > upperBound)]

    print("Outliers out of total = {} are \n {}".format(house[column].size,len(data[column])))
    #remove the outliers from the dataframe
    outlierRemoved = house[~house[column].isin(data[column])]
    return outlierRemoved

# %%
df_outliersRemoved = getOutliers(house,"total_rooms")
# Out:
# (IQR = 1693.0)Outlier are anything outside this range: (-1089.5,5682.5)
# Outliers out of total = 20433 are
#  1290

# %%
house.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
print ("Total_bedrooms column Mode is  "+str(house["total_bedrooms"].mode())+"\n")
print(house["total_bedrooms"].describe())
# Out:
# Total_bedrooms column Mode is  0    280.0
# dtype: float64
#
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
total_bedroms = house[house["total_bedrooms"].notnull()]["total_bedrooms"]#["total_bedrooms"]
total_bedroms.hist(figsize=(12,8),bins=50)
# Out:
# <AxesSubplot:>

# %%
print(house.iloc[:,4:5].head())
imp = SimpleImputer(strategy ="median")
imp.fit(house.iloc[:,4:5])
house.iloc[:,4:5] = imp.transform(house.iloc[:,4:5])
house.isnull().sum()
# Out:
#    total_bedrooms
# 0           129.0
# 1          1106.0
# 2           190.0
# 3           235.0
# 4           280.0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
labelEncoder = LabelEncoder()
print(house["ocean_proximity"].value_counts())
house["ocean_proximity"] = labelEncoder.fit_transform(house["ocean_proximity"])
house["ocean_proximity"].value_counts()
house.describe()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value  ocean_proximity
# count        20433.000000     20433.000000
# mean        206864.413155         1.166153
# std         115435.667099         1.420135
# min          14999.000000         0.000000
# 25%         119500.000000         0.000000
# 50%         179700.000000         1.000000
# 75%         264700.000000         1.000000
# max         500001.000000         4.000000

# %%
house_ind = house.drop("median_house_value",axis=1)
print(house_ind.head())
house_dep = house["median_house_value"]
print("Medain House Values")
print(house_dep.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  ocean_proximity
# 0         322         126         8.3252                3
# 1        2401        1138         8.3014                3
# 2         496         177         7.2574                3
# 3         558         219         5.6431                3
# 4         565         259         3.8462                3
# Medain House Values
# 0    452600
# 1    358500
# 2    352100
# 3    341300
# 4    342200
# Name: median_house_value, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(house_ind,house_dep,test_size=0.2,random_state=42)
#print(X_train.head())
#print(X_test.head())
#print(y_train.head())
#print(y_test.head())
print("X_train shape {} and size {}".format(X_train.shape,X_train.size))
print("X_test shape {} and size {}".format(X_test.shape,X_test.size))
print("y_train shape {} and size {}".format(y_train.shape,y_train.size))
print("y_test shape {} and size {}".format(y_test.shape,y_test.size))
# Out:
# X_train shape (16346, 9) and size 147114
# X_test shape (4087, 9) and size 36783
# y_train shape (16346,) and size 16346
# y_test shape (4087,) and size 4087

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17727    -121.80     37.32                  14         4412           924.0
# 2057     -119.63     36.64                  33         1036           181.0
# 6453     -118.06     34.12                  25         3891           848.0
# 4619     -118.31     34.07                  28         2362           949.0
# 15266    -117.27     33.04                  27         1839           392.0
#
#        population  households  median_income  ocean_proximity
# 17727        2698         891         4.7027                0
# 2057          620         174         3.4107                1
# 6453         1848         759         3.6639                1
# 4619         2759         894         2.2364                0
# 15266        1302         404         3.5500                4

# %%
#Standardize training and test datasets.
#==============================================================================
# Feature scaling is to bring all the independent variables in a dataset into
# same scale, to avoid any variable dominating  the model. Here we will not 
# transform the dependent variables.
#==============================================================================
independent_scaler = StandardScaler()
X_train = independent_scaler.fit_transform(X_train)
X_test = independent_scaler.transform(X_test)
print(X_train[0:5,:])
print("test data")
print(X_test[0:5,:])
# Out:
# [[-1.10651441  0.78620804 -1.16206244  0.82931106  0.92929666  1.13110981
#    1.04074393  0.43841173 -0.82241562]
#  [-0.02467137  0.46787317  0.34865716 -0.73855806 -0.85052345 -0.7088994
#   -0.85615229 -0.24238852 -0.12020053]
#  [ 0.75804456 -0.71183841 -0.2874353   0.58735021  0.74724238  0.37845927
#    0.69152454 -0.10896853 -0.12020053]
#  [ 0.63340827 -0.73524539 -0.04890063 -0.12274217  0.98918293  1.18512356
#    1.04868073 -0.86116849 -0.82241562]
#  [ 1.15189525 -1.21742909 -0.12841219 -0.36563185 -0.34508329 -0.10500803
#   -0.24766396 -0.16898645  1.98644475]]
# test data
# [[ 1.16685161 -1.33446397 -0.68499309 -0.77338928 -0.6181647  -0.79301917
#   -0.64450418 -0.36195011  1.98644475]
#  [-0.85225636  1.10922431 -2.11620113  1.75396373  1.38922326  1.68807122
#    1.21535362  0.32480451 -0.12020053]
#  [ 0.71816095 -0.80546631  0.18963404  0.51304362  0.75921964  0.79020339
#    0.8026398  -0.34092539 -0.82241562]
#  [-1.2411216   1.07645454  0.11012249 -0.63452883 -0.62295561 -0.63186341
#   -0.73180902 -0.51570979  1.28422966]
#  [-1.15138347  1.09986152 -1.95717801 -0.21144567  0.14598417 -0.43617427
#   -0.09686468  0.121671   -0.12020053]]

# %%
#initantiate the linear regression
linearRegModel = LinearRegression(n_jobs=-1)
#fit the model to the training data (learn the coefficients)
linearRegModel.fit(X_train,y_train)
#print the intercept and coefficients 
print("Intercept is "+str(linearRegModel.intercept_))
print("coefficients  is "+str(linearRegModel.coef_))
# Out:
# Intercept is 206644.4000978828
# coefficients  is [-85786.96930953 -90748.67284603  14548.78724736 -18030.45613035
#   48408.76930712 -41646.35936368  15673.5278147   76403.23016686
#    -561.22223864]

# %%
y_pred = linearRegModel.predict(X_test)

# %%
print(len(y_pred))
print(len(y_test))
print(y_pred[0:5])
print(y_test[0:5])
# Out:
# 4087
# 4087
# [195854.43379086 157564.349841   202476.8302992  173038.26811323
#  214022.31040522]
# 14416    245800
# 16383    137900
# 7731     218200
# 1410     220800
# 1335     170500
# Name: median_house_value, dtype: int64

# %%
test = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind='reg',);

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print(np.sqrt(metrics.mean_squared_error(y_train,linearRegModel.predict(X_train))))
# Out:
# 70171.99539639697
# 69409.6962582108

# %%
dtReg = DecisionTreeRegressor(max_depth=9)
dtReg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9)

# %%
dtReg_y_pred = dtReg.predict(X_test)
dtReg_y_pred
# Out:
# array([252394.11363636, 160493.29896907, 215541.88034188, ...,
#         78690.99099099, 135937.85069444, 114388.37209302])

# %%
print(len(dtReg_y_pred))
print(len(y_test))
print(dtReg_y_pred[0:5])
print(y_test[0:5])
# Out:
# 4087
# 4087
# [252394.11363636 160493.29896907 215541.88034188 125750.
#  160493.29896907]
# 14416    245800
# 16383    137900
# 7731     218200
# 1410     220800
# 1335     170500
# Name: median_house_value, dtype: int64

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,dtReg_y_pred)))
# Out:
# 60941.639938471846

# %%
test = pd.DataFrame({'Predicted':dtReg_y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind="reg")

# %%
rfReg = RandomForestRegressor(30)
rfReg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=30)

# %%
rfReg_y_pred = rfReg.predict(X_test)
print(len(rfReg_y_pred))
print(len(y_test))
print(rfReg_y_pred[0:5])
print(y_test[0:5])
# Out:
# 4087
# 4087
# [252866.76666667 148900.         200353.33333333 140780.
#  149393.33333333]
# 14416    245800
# 16383    137900
# 7731     218200
# 1410     220800
# 1335     170500
# Name: median_house_value, dtype: int64

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,rfReg_y_pred)))
# Out:
# 50309.38565381595

# %%
test = pd.DataFrame({'Predicted':dtReg_y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind="reg")

# %%
dropcol = ["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","ocean_proximity"]
print(dropcol)
house_med = house_ind.drop(dropcol,axis=1)
print(type(house_med))
# Out:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'ocean_proximity']
# <class 'pandas.core.frame.DataFrame'>

# %%
X_train2,X_test2,y_train2,y_test2 = train_test_split(house_med,house_dep,test_size=0.2,random_state=42)
#print(X_train.head())
#print(X_test.head())
#print(y_train.head())
#print(y_test.head())
print("X_train2 shape {} and size {}".format(X_train2.shape,X_train2.size))
print("X_test2 shape {} and size {}".format(X_test2.shape,X_test2.size))
print("y_train2 shape {} and size {}".format(y_train2.shape,y_train2.size))
print("y_test2 shape {} and size {}".format(y_test2.shape,y_test2.size))
# Out:
# X_train2 shape (16346, 1) and size 16346
# X_test2 shape (4087, 1) and size 4087
# y_train2 shape (16346,) and size 16346
# y_test2 shape (4087,) and size 4087

# %%
linReg2 = LinearRegression()
linReg2.fit(X_train2,y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = linReg2.predict(X_test2)
print(len(y_pred2))
print(len(y_test2))
print(y_pred2[0:5])
print(y_test2[0:5])
# Out:
# 4087
# 4087
# [177965.11196678 232380.43879174 179631.01508986 165781.89063053
#  216285.05899352]
# 14416    245800
# 16383    137900
# 7731     218200
# 1410     220800
# 1335     170500
# Name: median_house_value, dtype: int64

# %%
fig = plt.figure(figsize=(25,8))
plt.scatter(y_test2,y_pred2,marker="o",edgecolors ="r",s=60)
plt.scatter(y_train2,linReg2.predict(X_train2),marker="+",s=50,alpha=0.5)
plt.xlabel(" Actual median_house_value")
plt.ylabel(" Predicted median_house_value")
# Out:
# Text(0, 0.5, ' Predicted median_house_value')
